# %% [markdown]
# ## Урок 1
# #### Задание 4

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
x = np.linspace(-5,5,100)
y1 = np.cos(x)
y2 = np.cos(2*x)

# %%
plt.plot(x, y1)
plt.plot(x, y2)
